# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
from spectral_cube import SpectralCube
import numpy as np
import aplpy as apl
import matplotlib.pyplot as plt

almadir = '/Volumes/SD-Mac/Google Drive/research/bhr71_infall/analysis/imcontsub/'
spws = np.arange(0,4).astype('str')

# %%
for i, spw in enumerate(spws[0]):
    img = almadir+'spw'+spw+'_imcontsub.image.pbcor.fits'
    cube = SpectralCube.read(img) 
    moment_0 = cube.moment(order=0)
    moment_1 = cube.moment(order=1)
    moment_0.write(img.split('.fits')[0]+'.moment0.fits', overwrite=True)
    moment_1.write(img.split('.fits')[0]+'.moment1.fits', overwrite=True)
    
    
    f = aplpy.FITSFigure(moment_0.hdu)
    f.show_colorscale()
    f.save('moment_0.png')
# Out:
# /Users/yaolun/anaconda/envs/py36/lib/python3.6/site-packages/spectral_cube/spectral_cube.py:2031: UserWarning: Cube is a Stokes cube, returning spectral cube for I component
#   warnings.warn("Cube is a Stokes cube, "
# WARNING: A 'NAXIS1' keyword already exists in this header.  Inserting duplicate keyword. [astropy.io.fits.header]
# INFO: Auto-setting vmin to -7.673e+05 [aplpy.core]
# INFO: Auto-setting vmax to  5.840e+06 [aplpy.core]

# %%
moment_0.hdu.header
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                  -32 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                   70
# NAXIS2  =                   70
# BMAJ    =   0.0001115306012761
# BMIN    =   7.742983778365E-05
# BPA     =      -48.47638954375
# BTYPE   = 'Intensity'
# OBJECT  = 'bhr71   '
# BUNIT   = 'beam-1 Hz Jy'       / Brightness (pixel) unit
# ALTRVAL =   9.216298178351E+04 /Alternate frequency reference value
# ALTRPIX =   1.000000000000E+00 /Alternate frequency reference pixel
# VELREF  =                  257 /1 LSR, 2 HEL, 3 OBS, +256 Radio
# COMMENT casacore non-standard usage: 4 LSD, 5 GEO, 6 SOU, 7 GAL
# TELESCOP= 'ALMA    '
# OBSERVER= 'yaolun  '
# TIMESYS = 'UTC     '
# OBSRA   =   1.804033749999E+02
# OBSDEC  =  -6.514700555558E+01
# OBJECT  = 'bhr71   '
# TELESCOP= 'ALMA    '
# INSTRUME= 'ALMA    '
# DISTANCE=   0.000000000000E+00
# DATE    = '2018-04-06T20:18:00.917000' /Date FITS file was written
# ORIGIN  = 'CASA 5.1.1-5'
# WCSAXES =                    2
# CRPIX1  =                -10.0
# CRPIX2  =                 39.0
# CDELT1  =  -1.194444444444E-05
# CDELT2  =   1.194444444444E-05
# CUNIT1  = 'deg     '
# CUNIT2  = 'deg     '
# CTYPE1  = 'RA---SIN'
# CTYPE2  = 'DEC--SIN'
# CRVAL1  =       180.4033749999
# CRVAL2  =   -65.14700555557999
# LONPOLE =                180.0
# LATPOLE =   -65.14700555557999
# RESTFRQ =       354505473000.0
# RADESYS = 'ICRS    '
# SPECSYS = 'LSRK    '
# OBSGEO-X=       2225142.180269
# OBSGEO-Y=      -5440307.370349
# OBSGEO-Z=      -2481029.851874
# MJD-OBS =      57710.394468333
# DATE-OBS= '2016-11-18T09:28:02.064000'
# HISTORY CASA START LOGTABLE
# HISTORY 2018-02-21T23:28:49 INFO SRCCODE='::image::continuumsub'
# HISTORY Ran ia.continuumsub
# HISTORY 2018-02-21T23:28:49 INFO SRCCODE='::image::continuumsub'
# HISTORY ia.continuumsub(outline="spw0_imcontsub.image.pbcor", outcont="spw0_imco
# HISTORY >ntsub.image.pbcor.continuum", region={...}, channels=..., pol="", fitor
# HISTORY >er=2, overwrite=false)
# HISTORY 2018-02-21T23:28:49 INFO SRCCODE='::ImageProfileFitter::fit'
# HISTORY Number of profiles       = 4900
# HISTORY 2018-02-21T23:28:49 INFO SRCCODE='::ImageProfileFitter::fit'
# HISTORY Number of fits attempted = 4900
# HISTORY 2018-02-21T23:28:49 INFO SRCCODE='::ImageProfileFitter::fit'
# HISTORY Number succeeded         = 4900
# HISTORY 2018-02-21T23:28:49 INFO SRCCODE='::ImageProfileFitter::fit'
# HISTORY Number converged         = 4900
# HISTORY 2018-02-21T23:28:49 INFO SRCCODE='::ImageProfileFitter::fit'
# HISTORY Number valid             = 4900
# HISTORY CASA END LOGTABLE

# %%
import sys
sys.path.append('/Users/yaolun/programs/misc/')
from make_image import make_image
from astropy.coordinates import SkyCoord
from astropy import units as u
from astropy.io import fits
center = SkyCoord('12 01 36.81 -65 08 49.22', unit=(u.hourangle, u.deg))

# %%
center.ra.degree, center.dec.degree
# Out:
# (180.40337499999998, -65.14700555555557)

# %%
filepath = almadir+'spw0_imcontsub.image.pbcor.moment0.fits'

def plotMoment(filepath, save=False):
    from astropy.io import fits
    import aplpy as apl
    
    bunit = fits.open(filepath)[0].header['BUNIT']
    im = apl.FITSFigure(filepath, north=True)
    im.frame.set_linewidth(2)
    im.frame.set_color('black')
    cmap = plt.cm.viridis
    im.show_colorscale(cmap=cmap, stretch='sqrt', vmin=None, vmax=None)

    im.set_nan_color('white')
    im.tick_labels.set_font(size=18)

    im.add_colorbar()
    im.colorbar.set_font(size=18)
    im.colorbar.set_axis_label_text('Intensity ['+bunit+']')
    im.colorbar.set_axis_label_font(size=18)
    im.colorbar.set_frame_linewidth(2)
    # im.tick_labels.set_xformat('hh:mm:ss')
    # im.tick_labels.set_yformat('dd:mm:ss')
    im.ticks.set_xspacing('auto')
    im.ticks.set_yspacing('auto')
    im.axis_labels.set_font(size=18)
    im.ticks.set_linewidth(2)
    im.ticks.set_color('black')

#     im.show_markers(center.ra.degree, center.dec.degree, marker='+', c='white', s=120, linewidth=2)

    if save:
        im.save(filepath.split('.fits')[0]+'.pdf', format='pdf', transparent=True, dpi=300)
# Out:
#   File "<ipython-input-66-212561426529>", line 2
#     def plotMoment(filepath)
#                             ^
# SyntaxError: invalid syntax
